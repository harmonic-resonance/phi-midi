# %%
# !pip install --upgrade musicpy
# Out:
# ...
#      |████████████████████████████████| 107 kB 335 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 998 kB/s eta 0:00:01     |███████████████████████████████▊| 1.0 MB 998 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 21.9 MB 1.6 MB/s eta 0:00:01    |█▌                              | 1.1 MB 1.3 MB/s eta 0:00:16     |██████████▍                     | 7.1 MB 1.3 MB/s eta 0:00:12     |███████████                     | 7.5 MB 1.3 MB/s eta 0:00:11     |███████████████▌                | 10.6 MB 458 kB/s eta 0:00:25     |███████████████████▋            | 13.4 MB 1.4 MB/s eta 0:00:07     |██████████████████████▏         | 15.1 MB 1.6 MB/s eta 0:00:05     |████████████████████████▎       | 16.6 MB 1.4 MB/s eta 0:00:04     |████████████████████████████▉   | 19.7 MB 1.7 MB/s eta 0:00:02
# ...
#   Created wheel for musicpy: filename=musicpy-4.81-py3-none-any.whl size=97286 sha256=52dd54c7a310740ce170678461c303966f74524a3a2da355d60975d8c942ee13
# ...

# %%
# !pip install sf2_loader
# Out:
# ...
#      |████████████████████████████████| 7.6 MB 279 kB/s eta 0:00:01     |██████████████████▉             | 4.4 MB 1.7 MB/s eta 0:00:02     |████████████████████████████▋   | 6.7 MB 1.5 MB/s eta 0:00:01     |██████████████████████████████  | 7.1 MB 1.5 MB/s eta 0:00:01
# ...
#   Created wheel for sf2-loader: filename=sf2_loader-0.86-py3-none-any.whl size=7589786 sha256=ce70e2154c59cb754ca6abc1e6e748a205319962b70ce79266c13481c26bf859
#   Stored in directory: /home/illumiphi/.cache/pip/wheels/3b/f0/23/e5cfcf9bc8a892e3967987207f8e5f6af2b8ab9a58cb4261d2
# Successfully built sf2-loader
# ...

# %%
import sf2_loader as sf

# %%
# !sudo apt install -y fluidsynth
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libfluidsynth2 libinstpatch-1.0-2 libsdl2-2.0-0 qsynth timgm6mb-soundfont
# Suggested packages:
#   jackd
# The following NEW packages will be installed:
#   fluidsynth libfluidsynth2 libinstpatch-1.0-2 libsdl2-2.0-0 qsynth
#   timgm6mb-soundfont
# 0 upgraded, 6 newly installed, 0 to remove and 10 not upgraded.
# Need to get 6,748 kB of archives.
# After this operation, 10.4 MB of additional disk space will be used.
# Get:1 https://deb.debian.org/debian bullseye/main amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [259 kB]
# Get:2 https://deb.debian.org/debian bullseye/main amd64 libsdl2-2.0-0 amd64 2.0.14+dfsg2-3 [506 kB]
# Get:3 https://deb.debian.org/debian bullseye/main amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:4 https://deb.debian.org/debian bullseye/main amd64 libfluidsynth2 amd64 2.1.7-1.1 [227 kB]m
# ...

# %%
# !sudo apt install -y ffmpeg libavcodec-extra
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaribb24-0 libass9 libavc1394-0 libavcodec-extra58 libavdevice58
#   libavfilter7 libblas3 libbs2b0 libcaca0 libcdio-cdda2 libcdio-paranoia2
#   libcdio19 libdc1394-25 libflite1 libgfortran5 libiec61883-0 liblapack3
#   liblilv-0-0 libmysofa1 libopenal-data libopenal1 libopencore-amrnb0
#   libopencore-amrwb0 libpocketsphinx3 libpostproc55 libraw1394-11
#   librubberband2 libserd-0-0 libslang2 libsndio7.0 libsord-0-0 libsphinxbase3
#   libsratom-0-0 libswscale5 libvidstab1.1 libvo-amrwbenc0 pocketsphinx-en-us
# Suggested packages:
#   ffmpeg-doc libportaudio2 libraw1394-doc serdi sndiod sordi
# The following packages will be REMOVED:
#   libavcodec58
# The following NEW packages will be installed:
#   ffmpeg libaribb24-0 libass9 libavc1394-0 libavcodec-extra libavcodec-extra58
# ...

# %%
loader = sf.sf2_loader('KBH_Real_and_Swell_Choir.sf2')
# Out:
# fluidsynth: warning: SDL2 not initialized, SDL2 audio driver won't be usable
