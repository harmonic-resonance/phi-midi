# %%
import phi_midi as pm
import math as math

n = 144
root = 50
octaves = 5
scale_type = 'dorian'
scale_type = 'pentatonicmajor'
# scale_type = 'harmonicminor'
# scale_type = 'phrygian'
# scale_type = 'bluesmajor'
tempo=250000*2
pulse=120

phi = (1 + math.sqrt(5)) / 2
angle = (2 * math.pi) / phi

scale = pm.build_scale(
    root=root, 
    scale_type=scale_type, 
    octaves=octaves)

filename = f'{scale_type}-{n}-{octaves}.mid'
mf = pm.new_midi(title=filename)
mf.tracks[0].append(pm.MetaMessage('set_tempo', tempo=tempo, time=0))

vibes = pm.set_new_track(mf, name='vibes')
vibes.append(pm.Message('program_change', program=11, time=0))

gong = pm.set_new_track(mf, name='gong')
gong.append(pm.Message('program_change', program=32, channel=1, time=0))

angles = []

print('phi:', phi)
print('angle:', angle)
print('scale:', scale)

for i in range(n):
    theta = angle * i
    angles.append(theta)
    
sins = list(map(lambda x: math.sin(x), angles))
coss = list(map(lambda x: math.cos(x), angles))

def get_note(x):
    '''range -1 to 1'''
    divs = len(scale)
    i = int((x+1)/2 * divs)
    return scale[i]
    
def get_pan(x):
    '''range -1 to 1'''
    divs = 127
    i = int((x+1)/2 * divs)
    return i
    
notes = list(map(get_note, sins))
pans = list(map(get_pan, coss))

for i, note in enumerate(notes):
    vibes.append(pm.Message('control_change', control=10, value=pans[i], time=0))
    pm.set_note(vibes, note, duration=pulse)

gongs = int(n / octaves)
gong_gap = octaves * pulse

root -= 12

for i in range(gongs):
    if i > gongs/phi:
        # set_note(gong, root+(octaves-1)*12, channel=1, duration=gong_gap)
        pm.set_note(gong, root, channel=1, duration=gong_gap)
    else:
        pm.set_note(gong, root-12, channel=1, duration=gong_gap)

mf.save(filename)

# !timidity $filename
# Out:
# phi: 1.618033988749895
# angle: 3.8832220774509327
# scale: [50, 52, 54, 57, 59, 62, 64, 66, 69, 71, 74, 76, 78, 81, 83, 86, 88, 90, 93, 95, 98, 100, 102, 105, 107, 110]
# Playing pentatonicmajor-144-5.mid
# MIDI file: pentatonicmajor-144-5.mid
# Format: 1  Tracks: 3  Divisions: 480
# Sequence: meta
# Text: pentatonicmajor-144-5.mid
# Track name: vibes
# Track name: gong
# ^C
# Terminated sig=0x02

# %%
import phi_midi as pm

# %%
# Out:
# === Track 0
# MetaMessage('track_name', name='meta', time=0)
# MetaMessage('text', text='pentatonicmajor-144-5.mid', time=0)
# MetaMessage('set_tempo', tempo=500000, time=0)
# === Track 1
# MetaMessage('track_name', name='vibes', time=0)
# Message('program_change', channel=0, program=11, time=0)
# Message('control_change', channel=0, control=10, value=127, time=0)
# Message('note_on', channel=0, note=81, velocity=64, time=0)
# Message('note_off', channel=0, note=81, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=16, time=0)
# Message('note_on', channel=0, note=59, velocity=64, time=0)
# Message('note_off', channel=0, note=59, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=69, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=102, time=0)
# Message('note_on', channel=0, note=54, velocity=64, time=0)
# Message('note_off', channel=0, note=54, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=0, time=0)
# Message('note_on', channel=0, note=86, velocity=64, time=0)
# Message('note_off', channel=0, note=86, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=117, time=0)
# Message('note_on', channel=0, note=95, velocity=64, time=0)
# Message('note_off', channel=0, note=95, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=47, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=34, time=0)
# Message('note_on', channel=0, note=107, velocity=64, time=0)
# Message('note_off', channel=0, note=107, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=123, time=0)
# Message('note_on', channel=0, note=69, velocity=64, time=0)
# Message('note_off', channel=0, note=69, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=4, time=0)
# Message('note_on', channel=0, note=69, velocity=64, time=0)
# Message('note_off', channel=0, note=69, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=90, time=0)
# Message('note_on', channel=0, note=107, velocity=64, time=0)
# Message('note_off', channel=0, note=107, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=82, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=8, time=0)
# Message('note_on', channel=0, note=95, velocity=64, time=0)
# Message('note_off', channel=0, note=95, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=125, time=0)
# Message('note_on', channel=0, note=86, velocity=64, time=0)
# Message('note_off', channel=0, note=86, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=26, time=0)
# Message('note_on', channel=0, note=54, velocity=64, time=0)
# Message('note_off', channel=0, note=54, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=55, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=112, time=0)
# Message('note_on', channel=0, note=59, velocity=64, time=0)
# Message('note_off', channel=0, note=59, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=0, time=0)
# Message('note_on', channel=0, note=78, velocity=64, time=0)
# Message('note_off', channel=0, note=78, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=108, time=0)
# Message('note_on', channel=0, note=102, velocity=64, time=0)
# Message('note_off', channel=0, note=102, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=60, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=22, time=0)
# Message('note_on', channel=0, note=102, velocity=64, time=0)
# Message('note_off', channel=0, note=102, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=126, time=0)
# Message('note_on', channel=0, note=76, velocity=64, time=0)
# Message('note_off', channel=0, note=76, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=11, time=0)
# Message('note_on', channel=0, note=62, velocity=64, time=0)
# Message('note_off', channel=0, note=62, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=77, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=95, time=0)
# Message('note_on', channel=0, note=52, velocity=64, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=3, time=0)
# Message('note_on', channel=0, note=88, velocity=64, time=0)
# Message('note_off', channel=0, note=88, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=121, time=0)
# Message('note_on', channel=0, note=93, velocity=64, time=0)
# Message('note_off', channel=0, note=93, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=38, time=0)
# Message('note_on', channel=0, note=52, velocity=64, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=42, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=119, time=0)
# Message('note_on', channel=0, note=64, velocity=64, time=0)
# Message('note_off', channel=0, note=64, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=2, time=0)
# Message('note_on', channel=0, note=71, velocity=64, time=0)
# Message('note_off', channel=0, note=71, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=97, time=0)
# Message('note_on', channel=0, note=105, velocity=64, time=0)
# Message('note_off', channel=0, note=105, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=74, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=13, time=0)
# Message('note_on', channel=0, note=98, velocity=64, time=0)
# Message('note_off', channel=0, note=98, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=126, time=0)
# Message('note_on', channel=0, note=83, velocity=64, time=0)
# Message('note_off', channel=0, note=83, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=20, time=0)
# Message('note_on', channel=0, note=57, velocity=64, time=0)
# Message('note_off', channel=0, note=57, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=63, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=106, time=0)
# Message('note_on', channel=0, note=57, velocity=64, time=0)
# Message('note_off', channel=0, note=57, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=0, time=0)
# Message('note_on', channel=0, note=83, velocity=64, time=0)
# Message('note_off', channel=0, note=83, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=114, time=0)
# Message('note_on', channel=0, note=98, velocity=64, time=0)
# Message('note_off', channel=0, note=98, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=52, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=29, time=0)
# Message('note_on', channel=0, note=107, velocity=64, time=0)
# Message('note_off', channel=0, note=107, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=124, time=0)
# Message('note_on', channel=0, note=71, velocity=64, time=0)
# Message('note_off', channel=0, note=71, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=7, time=0)
# Message('note_on', channel=0, note=66, velocity=64, time=0)
# Message('note_off', channel=0, note=66, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=85, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=87, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=6, time=0)
# Message('note_on', channel=0, note=93, velocity=64, time=0)
# Message('note_off', channel=0, note=93, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=124, time=0)
# Message('note_on', channel=0, note=88, velocity=64, time=0)
# Message('note_off', channel=0, note=88, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=31, time=0)
# Message('note_on', channel=0, note=52, velocity=64, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=50, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=115, time=0)
# Message('note_on', channel=0, note=62, velocity=64, time=0)
# Message('note_off', channel=0, note=62, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=0, time=0)
# Message('note_on', channel=0, note=76, velocity=64, time=0)
# Message('note_off', channel=0, note=76, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=104, time=0)
# Message('note_on', channel=0, note=102, velocity=64, time=0)
# Message('note_off', channel=0, note=102, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=65, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=18, time=0)
# Message('note_on', channel=0, note=102, velocity=64, time=0)
# Message('note_off', channel=0, note=102, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=126, time=0)
# Message('note_on', channel=0, note=78, velocity=64, time=0)
# Message('note_off', channel=0, note=78, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=14, time=0)
# Message('note_on', channel=0, note=59, velocity=64, time=0)
# Message('note_off', channel=0, note=59, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=72, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=99, time=0)
# Message('note_on', channel=0, note=54, velocity=64, time=0)
# Message('note_off', channel=0, note=54, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=1, time=0)
# Message('note_on', channel=0, note=86, velocity=64, time=0)
# Message('note_off', channel=0, note=86, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=118, time=0)
# Message('note_on', channel=0, note=95, velocity=64, time=0)
# Message('note_off', channel=0, note=95, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=43, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=37, time=0)
# Message('note_on', channel=0, note=107, velocity=64, time=0)
# Message('note_off', channel=0, note=107, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=121, time=0)
# Message('note_on', channel=0, note=66, velocity=64, time=0)
# Message('note_off', channel=0, note=66, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=3, time=0)
# Message('note_on', channel=0, note=69, velocity=64, time=0)
# Message('note_off', channel=0, note=69, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=93, time=0)
# Message('note_on', channel=0, note=107, velocity=64, time=0)
# Message('note_off', channel=0, note=107, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=79, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=10, time=0)
# Message('note_on', channel=0, note=98, velocity=64, time=0)
# Message('note_off', channel=0, note=98, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=126, time=0)
# Message('note_on', channel=0, note=86, velocity=64, time=0)
# Message('note_off', channel=0, note=86, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=24, time=0)
# Message('note_on', channel=0, note=54, velocity=64, time=0)
# Message('note_off', channel=0, note=54, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=58, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=109, time=0)
# Message('note_on', channel=0, note=59, velocity=64, time=0)
# Message('note_off', channel=0, note=59, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=0, time=0)
# Message('note_on', channel=0, note=81, velocity=64, time=0)
# Message('note_off', channel=0, note=81, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=110, time=0)
# Message('note_on', channel=0, note=100, velocity=64, time=0)
# Message('note_off', channel=0, note=100, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=57, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=25, time=0)
# Message('note_on', channel=0, note=105, velocity=64, time=0)
# Message('note_off', channel=0, note=105, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=125, time=0)
# Message('note_on', channel=0, note=74, velocity=64, time=0)
# Message('note_off', channel=0, note=74, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=9, time=0)
# Message('note_on', channel=0, note=64, velocity=64, time=0)
# Message('note_off', channel=0, note=64, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=80, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=92, time=0)
# Message('note_on', channel=0, note=52, velocity=64, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=4, time=0)
# Message('note_on', channel=0, note=90, velocity=64, time=0)
# Message('note_off', channel=0, note=90, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=122, time=0)
# Message('note_on', channel=0, note=90, velocity=64, time=0)
# Message('note_off', channel=0, note=90, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=36, time=0)
# Message('note_on', channel=0, note=52, velocity=64, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=45, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=118, time=0)
# Message('note_on', channel=0, note=64, velocity=64, time=0)
# Message('note_off', channel=0, note=64, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=1, time=0)
# Message('note_on', channel=0, note=74, velocity=64, time=0)
# Message('note_off', channel=0, note=74, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=100, time=0)
# Message('note_on', channel=0, note=105, velocity=64, time=0)
# Message('note_off', channel=0, note=105, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=71, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=15, time=0)
# Message('note_on', channel=0, note=100, velocity=64, time=0)
# Message('note_off', channel=0, note=100, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=126, time=0)
# Message('note_on', channel=0, note=81, velocity=64, time=0)
# Message('note_off', channel=0, note=81, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=18, time=0)
# Message('note_on', channel=0, note=57, velocity=64, time=0)
# Message('note_off', channel=0, note=57, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=67, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=103, time=0)
# Message('note_on', channel=0, note=54, velocity=64, time=0)
# Message('note_off', channel=0, note=54, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=0, time=0)
# Message('note_on', channel=0, note=83, velocity=64, time=0)
# Message('note_off', channel=0, note=83, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=115, time=0)
# Message('note_on', channel=0, note=98, velocity=64, time=0)
# Message('note_off', channel=0, note=98, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=48, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=32, time=0)
# Message('note_on', channel=0, note=107, velocity=64, time=0)
# Message('note_off', channel=0, note=107, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=123, time=0)
# Message('note_on', channel=0, note=69, velocity=64, time=0)
# Message('note_off', channel=0, note=69, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=5, time=0)
# Message('note_on', channel=0, note=66, velocity=64, time=0)
# Message('note_off', channel=0, note=66, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=88, time=0)
# Message('note_on', channel=0, note=107, velocity=64, time=0)
# Message('note_off', channel=0, note=107, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=84, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=7, time=0)
# Message('note_on', channel=0, note=95, velocity=64, time=0)
# Message('note_off', channel=0, note=95, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=125, time=0)
# Message('note_on', channel=0, note=88, velocity=64, time=0)
# Message('note_off', channel=0, note=88, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=28, time=0)
# Message('note_on', channel=0, note=54, velocity=64, time=0)
# Message('note_off', channel=0, note=54, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=53, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=113, time=0)
# Message('note_on', channel=0, note=59, velocity=64, time=0)
# Message('note_off', channel=0, note=59, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=0, time=0)
# Message('note_on', channel=0, note=78, velocity=64, time=0)
# Message('note_off', channel=0, note=78, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=107, time=0)
# Message('note_on', channel=0, note=102, velocity=64, time=0)
# Message('note_off', channel=0, note=102, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=62, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=21, time=0)
# Message('note_on', channel=0, note=102, velocity=64, time=0)
# Message('note_off', channel=0, note=102, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=126, time=0)
# Message('note_on', channel=0, note=76, velocity=64, time=0)
# Message('note_off', channel=0, note=76, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=12, time=0)
# Message('note_on', channel=0, note=62, velocity=64, time=0)
# Message('note_off', channel=0, note=62, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=75, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=96, time=0)
# Message('note_on', channel=0, note=52, velocity=64, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=2, time=0)
# Message('note_on', channel=0, note=88, velocity=64, time=0)
# Message('note_off', channel=0, note=88, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=120, time=0)
# Message('note_on', channel=0, note=93, velocity=64, time=0)
# Message('note_off', channel=0, note=93, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=40, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=40, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=120, time=0)
# Message('note_on', channel=0, note=66, velocity=64, time=0)
# Message('note_off', channel=0, note=66, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=2, time=0)
# Message('note_on', channel=0, note=71, velocity=64, time=0)
# Message('note_off', channel=0, note=71, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=96, time=0)
# Message('note_on', channel=0, note=107, velocity=64, time=0)
# Message('note_off', channel=0, note=107, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=76, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=12, time=0)
# Message('note_on', channel=0, note=98, velocity=64, time=0)
# Message('note_off', channel=0, note=98, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=126, time=0)
# Message('note_on', channel=0, note=83, velocity=64, time=0)
# Message('note_off', channel=0, note=83, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=21, time=0)
# Message('note_on', channel=0, note=57, velocity=64, time=0)
# Message('note_off', channel=0, note=57, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=61, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=107, time=0)
# Message('note_on', channel=0, note=57, velocity=64, time=0)
# Message('note_off', channel=0, note=57, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=0, time=0)
# Message('note_on', channel=0, note=81, velocity=64, time=0)
# Message('note_off', channel=0, note=81, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=112, time=0)
# Message('note_on', channel=0, note=100, velocity=64, time=0)
# Message('note_off', channel=0, note=100, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=54, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=27, time=0)
# Message('note_on', channel=0, note=105, velocity=64, time=0)
# Message('note_off', channel=0, note=105, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=125, time=0)
# Message('note_on', channel=0, note=71, velocity=64, time=0)
# Message('note_off', channel=0, note=71, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=7, time=0)
# Message('note_on', channel=0, note=64, velocity=64, time=0)
# Message('note_off', channel=0, note=64, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=83, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=89, time=0)
# Message('note_on', channel=0, note=52, velocity=64, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=5, time=0)
# Message('note_on', channel=0, note=93, velocity=64, time=0)
# Message('note_off', channel=0, note=93, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=123, time=0)
# Message('note_on', channel=0, note=90, velocity=64, time=0)
# Message('note_off', channel=0, note=90, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=33, time=0)
# Message('note_on', channel=0, note=52, velocity=64, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=48, time=0)
# Message('note_on', channel=0, note=110, velocity=64, time=0)
# Message('note_off', channel=0, note=110, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=116, time=0)
# Message('note_on', channel=0, note=62, velocity=64, time=0)
# Message('note_off', channel=0, note=62, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=0, time=0)
# Message('note_on', channel=0, note=74, velocity=64, time=0)
# Message('note_off', channel=0, note=74, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=103, time=0)
# Message('note_on', channel=0, note=105, velocity=64, time=0)
# Message('note_off', channel=0, note=105, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=67, time=0)
# Message('note_on', channel=0, note=50, velocity=64, time=0)
# Message('note_off', channel=0, note=50, velocity=127, time=120)
# Message('control_change', channel=0, control=10, value=17, time=0)
# Message('note_on', channel=0, note=100, velocity=64, time=0)
# Message('note_off', channel=0, note=100, velocity=127, time=120)
# === Track 2
# MetaMessage('track_name', name='gong', time=0)
# Message('program_change', channel=1, program=32, time=0)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=26, velocity=64, time=0)
# Message('note_off', channel=1, note=26, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)
# Message('note_on', channel=1, note=38, velocity=64, time=0)
# Message('note_off', channel=1, note=38, velocity=127, time=600)

# %%
pm.build_scale(root=60)
# Out:
# [60,
#  62,
#  64,
#  65,
#  67,
#  69,
#  71,
#  72,
#  74,
#  76,
#  77,
#  79,
#  81,
#  83,
#  84,
#  86,
#  88,
#  89,
#  91,
#  93,
#  95,
#  96]
